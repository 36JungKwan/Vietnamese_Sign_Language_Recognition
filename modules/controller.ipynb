# %%
# %load_ext autoreload
# %autoreload 2

from train import main

main()
# Out:
# 🚀 [1] Đang nạp thư viện PyTorch...
# ✅ [2] Đã nạp xong thư viện! Bắt đầu chạy code...
# 🔒 Đã khóa Seed ở mức 42. Kết quả huấn luyện sẽ nhất quán 100%!
# 📁 Mọi kết quả của lần chạy này sẽ được lưu an toàn tại: checkpoints\st_tr\baseline_20260916_0036
# Bắt đầu huấn luyện trên thiết bị: cuda
# 📊 [Tập TRAIN] Nạp thành công 24765 video. (Thiếu 0 file).
# 📊 [Tập TEST] Nạp thành công 5289 video. (Thiếu 0 file).
# ✅ Đã xuất từ điển ra file label_map_472.json
# 🚀 [MODEL FACTORY] Đang khởi tạo kiến trúc: ST_TR
# 🔍 Đang phân tích phần cứng (Memory, FLOPS, Inference Speed)...
# 📊 Report: 2.17M Params | 9.37 MB | 3.89G FLOPS | Speed: 304 FPS
#
# Epoch 1/50
# Training:   0%|          | 0/387 [00:00<?, ?it/s]c:\Users\dotru\STUDIE\Competition\Sang_tao_tre_AI\VSL_pipeline\modules\train.py:121: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# ...
