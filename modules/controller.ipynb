# %%
from extract_keypoints import main
import multiprocessing as mproc

mproc.freeze_support()
main()
# Out:
# ⏳ Đang quét kiểm tra tiến độ cũ (Tính năng Resume)...
# 🔍 Tổng tài nguyên: 30054 videos.
# ⏩ [RESUME] Đã bỏ qua 30053 video xử lý từ trước.
# ⏳ Nhiệm vụ còn lại: 1 videos.
# 🚀 Kích hoạt ĐỘNG CƠ 14 NHÂN CPU. Chuẩn bị cày...
# 🔥 Tiến độ: 100%|██████████| 1/1 [00:09<00:00,  9.18s/it]

# %%
# %load_ext autoreload
# %autoreload 2

from train import main

main()
# Out:
# 🚀 [1] Đang nạp thư viện PyTorch...
# ✅ [2] Đã nạp xong thư viện! Bắt đầu chạy code...
# 🔒 Đã khóa Seed ở mức 42. Kết quả huấn luyện sẽ nhất quán 100%!
# 📁 Mọi kết quả của lần chạy này sẽ được lưu an toàn tại: checkpoints\ctr_gcn\baseline_20260917_1148
# Bắt đầu huấn luyện trên thiết bị: cuda
# 📊 [Tập TRAIN] Nạp 24765 video thật. Sinh thêm 2476 video IDLE. (Thiếu 0 file).
# 📊 [Tập TEST] Nạp 5289 video thật. Sinh thêm 528 video IDLE. (Thiếu 0 file).
# ✅ Đã xuất từ điển ra file label_map_472.json
# 🚀 [MODEL FACTORY] Đang khởi tạo kiến trúc: CTR_GCN
# 🔍 Đang phân tích phần cứng (Memory, FLOPS, Inference Speed)...
# 📊 Report: 0.44M Params | 1.74 MB | 1.38G FLOPS | Speed: 379 FPS
#
# Epoch 1/100
# Training:   0%|          | 0/213 [00:00<?, ?it/s]c:\Users\dotru\STUDIE\Competition\Sang_tao_tre_AI\VSL_pipeline\modules\train.py:121: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# ...
